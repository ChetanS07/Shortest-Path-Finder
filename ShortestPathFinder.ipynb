# %% [markdown]
# <a href="https://colab.research.google.com/github/ChetanS07/Shortest-Path-Finder/blob/main/ShortestPathFinder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Fully Optimized
#Location latitude and longitude can be read from csv file aswell

# import statements
import folium
from folium import plugins
from numpy import append

import os
import ipywidgets
import json
from IPython. display import clear_output
###########

# creating a map instance 
defaultLocation = (13.034702, 77.565557)
myMap = folium.Map(location = defaultLocation, width = "100%%",height = "90%", zoom_start = 18,top="5.0%")
##############################################################################

# variables to store the distance between nodes and next nearest nodes
MAXM, INF = 100, 10**7
dis = [[-1 for i in range(MAXM)] for i in range(MAXM)]
Next = [[-1 for i in range(MAXM)] for i in range(MAXM)]

# other variables
noOfLocations = 30
source = 0 #starting point 
destination = 0 #ending point
path = [] 
antPath = []  #for adding the animated path to map
totalDistance = 0

#list of Location of all nodes(Latitude,Longitude)
location = []
location.append([13.0356972563827, 77.5645387172699])
location.append([13.0354032838366, 77.564478367567])
location.append([13.0350387573945, 77.5643670558929])
location.append([13.0346846828094, 77.5642450153828])
location.append([13.0356345422688, 77.5648377835751])
location.append([13.0351667990016, 77.5647546350956])
location.append([13.0356593666075, 77.5651274621487])
location.append([13.03509232583, 77.5650429725647])
location.append([13.0348754389218, 77.565009444952])
location.append([13.0342156311953, 77.5647841393948])
location.append([13.0356253964592, 77.5654788315296])
location.append([13.0339575871009, 77.5650905817747])
location.append([13.0356123310163, 77.5657477229834])
location.append([13.0345527213031, 77.5655418634415])
location.append([13.0342887980794, 77.5654935836792])
location.append([13.0340327138903, 77.5654372572899])
location.append([13.0338341178062, 77.5653809309006])
location.append([13.0337374328128, 77.565284371376])
location.append([13.0355639888717, 77.5660702586174])
location.append([13.0352843881743, 77.5660461187363])
location.append([13.0347826739814, 77.5659415125847])
location.append([13.0335283840494, 77.5655847787857])
location.append([13.0355744412281, 77.5665114820004])
location.append([13.0352478048821, 77.5665128231048])
location.append([13.0347173465377, 77.5664511322975])
location.append([13.0343867894081, 77.5664243102074])
location.append([13.0341842739526, 77.5664028525353])
location.append([13.0339412551872, 77.5663626194])
location.append([13.0337113017271, 77.5663411617279])
location.append([13.0334787349422, 77.5663009285927])

# adjacency matrix for the nodes
graph = [
        [0, 3, INF, INF, 3, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF],
        [3, 0, 4, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF],
        [INF, 4, 0, 4, INF, INF, INF, INF, 6, INF, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF],
        [INF, INF, 4, 0, INF, INF, INF, INF, INF, 7, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF],
        [3, INF, INF, INF, 0, 5, 3, INF, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF],
        [INF, INF, INF, INF, 5, 0, INF, 3, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF],
        [INF, INF, INF, INF, 3, INF, 0, 6, INF, INF, 4, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF],
        [INF, INF, INF, INF, INF, 3, 6, 0, 3,INF, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF],
        [INF, INF, 6, INF, INF, INF, INF, 3, 0, 10, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF],
        [INF, INF, INF, 7, INF, INF, INF, INF, 7, 0, INF, 4, INF, INF, INF, INF,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, 4, INF, INF, INF, 0, 20, 2, INF, INF, INF,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, 4, 20, 0, INF, INF, INF,
            INF, INF, 3, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 2, INF, 0, 12, INF,
            INF, INF, INF, 3, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 12, 0, 3,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 9, INF, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 3, 0,
            3, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 8, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 3,
            0, 3, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 8, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, 3, 0, 2, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 8, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 3, INF, INF, INF,
            INF, 2, 0, INF, INF, INF, 3, INF, INF, INF, INF, INF, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 3, INF, INF,
            INF, INF, INF, 0, 3, INF, INF, 5, INF, INF, INF, INF, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, 3, 0, 7, INF, INF, 5, INF, INF, INF, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, 7, 0, INF, INF, INF, 5, INF, INF, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, INF, 3, INF, INF, INF, 0, INF, INF, INF, INF, INF, INF, INF, 6],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, 5, INF, INF, INF, 0, 4, INF, INF, INF, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, INF, 5, INF, INF, 4, 0, 6, INF, INF, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, INF, INF, 5, INF, INF, 6, 0, 4, INF, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 9, INF,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, 4, 0, 3, INF, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 8,
            INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 3, 0, 3, INF, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, 8, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 3, 0, 3, INF],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, INF, 8, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, 3, 0, 3],
        [INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF, INF,
            INF, INF, INF, INF, INF, INF, INF, 6, INF, INF, INF, INF, INF, INF, 3, 0]
    ]

#functions
# function to initialize the arrays 'dis' and 'Next'
def initialise(V):
    global dis, Next

    for i in range(V):
        for j in range(V):
            dis[i][j] = graph[i][j]

            # No edge between node
            # i and j
            if (graph[i][j] == INF):
                Next[i][j] = -1
            else:
                Next[i][j] = j

# function to add markers to the map
def addMarkersAndConstructAntPath(u):
    global mymap,antPath

    antPath.append(location[u])
    # print(antPath[u])
    if (u == 0) and ((source == u) or (destination == u)):
        folium.Marker(
                      location=location[0],
                      popup= folium.map.Popup(html = 'Bus Stop',max_width ='100%',show=True, sticky=True),
                      icon=folium.Icon(icon="fa-bus",color='black',angle=330,prefix='fa'),
                  ).add_to(myMap)
    if (u == 1) and ((source == u) or (destination == u)):
        folium.Marker(
                      location=location[1],
                      popup= folium.map.Popup(html = 'Laundry',max_width ='100%',show=True, sticky=True),
                      icon=folium.Icon(icon="fa-shopping-basket",color='gray',prefix='fa'),
                  ).add_to(myMap)
    if u == 2:
        folium.Marker(
                      location=location[2],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)
    if u == 3 and ((source == u) or (destination == u)):
        folium.Marker(
                    location=location[3],
                    popup= folium.map.Popup(html = 'Homely',max_width ='100%',show=True, sticky=True),
                    icon=folium.Icon(icon="fa-free-code-camp",color='gray',prefix='fa'),
                  ).add_to(myMap)
    if u == 4:
        folium.Marker(
                      location=location[4],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)
    if u == 5:
        folium.Marker(
                      location=location[5],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)
    if u == 6:
        folium.Marker(
                      location=location[6],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)
    if u == 7:
        folium.Marker(
                      location=location[7],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)
    if (u == 8) and ((source == u) or (destination == u)):
        folium.Marker(
                      location=location[8],
                      popup= folium.map.Popup(html = 'Delhi Mess',max_width ='100%',show=True, sticky=True),
                      icon=folium.Icon(icon="fa-fire",color='darkred',angle=330,prefix='fa'),
                  ).add_to(myMap)
    if u == 9:
        folium.Marker(
                      location=location[9],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)
    if (u == 10) and ((source == u) or (destination == u)):
        folium.Marker(
                      location=location[10],
                      popup= folium.map.Popup(html = 'Srishti PG',max_width ='100%',show=True, sticky=True),
                      icon=folium.Icon(icon="fa-home",color='purple',prefix='fa'),
                  ).add_to(myMap)
    if (u == 11) and ((source == u) or (destination == u)):
        folium.Marker(
                      location=location[11],
                      popup= folium.map.Popup(html = 'Benaka Boys Hostel',show=True, sticky=True),
                      icon=folium.Icon(icon="fa-bed",color='purple',prefix='fa'),
                  ).add_to(myMap)
    if u == 12:
        folium.Marker(
                      location=location[12],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)
    if u == 13:
        folium.Marker(
                      location=location[13],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)
    if u == 14:
        folium.Marker(
                      location=location[14],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)
    if u == 15:
        folium.Marker(
                      location=location[15],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)
    if u == 16:
        folium.Marker(
                      location=location[16],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)
    if u == 17:
        folium.Marker(
                      location=location[17],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)
    if u == 18:
        folium.Marker(
                      location=location[18],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)                 
    if u == 19:
        folium.Marker(
                      location=location[19],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                    ).add_to(myMap)                  
    if (u == 20) and ((source == u) or (destination == u)):
        folium.Marker(
                      location=location[20],
                      popup= folium.map.Popup(html = 'More SuperMarket',max_width ='100%',show=True, sticky=True),
                      icon=folium.Icon(icon="fa-shopping-cart",color='cadetblue',angle=330,prefix='fa'),
                    ).add_to(myMap)
    if (u == 21) and ((source == u) or (destination == u)):
        folium.Marker(
                      location=location[21],
                      popup= folium.map.Popup(html = 'Urmidi Fastfood',max_width ='100%',show=True, sticky=True),
                      icon=folium.Icon(icon="fa-fire",color='darkred',angle=330,prefix='fa'),
                      ).add_to(myMap)
    if (u == 22) and ((source == u) or (destination == u)):
        folium.Marker(
                      location=location[22],
                      popup= folium.map.Popup(html = 'Anjaneya Swami Temple',max_width ='100%',show=True, sticky=True),
                      icon=folium.Icon(icon="fa-bell",color='orange',prefix='fa'),
                    ).add_to(myMap)
    if u == 23:
        folium.Marker(
                      location=location[23],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                  ).add_to(myMap)
    if u == 24:
        folium.Marker(
                      location=location[24],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                    ).add_to(myMap)
    if (u == 25) and ((source == u) or (destination == u)):
        folium.Marker(
                      location=location[25],
                      popup= folium.map.Popup(html = 'Play Ground',max_width ='100%',show=True, sticky=True),
                      icon=folium.Icon(icon="fa-trophy",color='darkgreen',angle=330,prefix='fa'),
                    ).add_to(myMap)
    if u == 26:
        folium.Marker(
                      location=location[26],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                    ).add_to(myMap)
    if u == 27:
        folium.Marker(
                      location=location[27],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                      ).add_to(myMap)
    if (u == 28) and ((source == u) or (destination == u)):
        folium.Marker(
                      location=location[28],
                      popup= folium.map.Popup(html = 'TT QuickBites',show=True, sticky=True),
                      icon=folium.Icon(icon="fa-glass",color='darkred',angle=330,prefix='fa'),
                      ).add_to(myMap)
    if u == 29:
        folium.Marker(
                      location=location[29],
                      tooltip = (totalDistance),
                      # popup= folium.map.Popup(html = 'Navigator',max_width ='100%',show=True),
                      icon=folium.Icon(icon="fa-location-arrow",color='lightblue',prefix='fa'),
                    ).add_to(myMap)

# function to create shortest path
def constructPath(u, v):
    global graph, Next,antPath

    # antPath.clear()

    # if no path exist
    if (Next[u][v] == -1):
        return {}

    # Storing the path in a vector
    path = [u]
    # constructAntPath(u)
    while (u != v):
        u = Next[u][v]
        # constructAntPath(u)
        path.append(u)

    return path

# Algorithm
def floydWarshall(V):
    global dist, Next
    for k in range(V):
        for i in range(V):
            for j in range(V):
                if (dis[i][k] == INF or dis[k][j] == INF):
                    continue
                if (dis[i][j] > dis[i][k] + dis[k][j]):
                    dis[i][j] = dis[i][k] + dis[k][j]
                    Next[i][j] = Next[i][k]

# Print the shortest path
def printPath(path):
    n = len(path)
    for i in range(n - 1):
        print(path[i], end=" -> ")
    print(path[n - 1])

#function to calculte the total distance between two points
def calculateTotalDistance(path):
    global totalDistance,antPath
    antPath.clear()
    i = 0
    addMarkersAndConstructAntPath(path[0])
    while i < len(path)-1:
      totalDistance = totalDistance + dis[path[i]][path[i+1]]
      u= path[i+1]
      addMarkersAndConstructAntPath(u)
      i = i+1

#function to call basic functions
def callBasicFunctions():
    global path,totalDistance,myMap

    initialise(noOfLocations)
    floydWarshall(noOfLocations)
    path = constructPath(source, destination)
    calculateTotalDistance(path)



"""
sources = {
          '10': 'Srishti PG'
          '11': 'Benaka Boys Hostel'
}
destinations = {
                '0':'Bus Stop'
                '1':'Laundry'
                '8':'Delhi Mess'
                '21':'Urmidi Fastfood'
                '20':'More SuperMarket'
                '22':'Anjaneya Swami Temple'
                '25':'Ground'
                '28':'TT Quick Bites'
}
"""

def drawMap():
    global myMap,totalDistance
    totalDistance = 0
    myMap = folium.Map(location = defaultLocation, width = "100%%",height = "90%", zoom_start = 18,top="5.0%")
    # path = constructPath(source, destination)
    # calculateTotalDistance(path)
    callBasicFunctions()
    print("\nTHE TOTAL DISTANCE COVERED : " + str(totalDistance))
    folium.plugins.AntPath([antPath]).add_to(myMap)
    display(myMap)
    # print(path)
    clear_output(wait=True)

def getSource():
    ipywidgets.interact(selectSource, startLoc=selectSourceWidget)

def getDestination():
     ipywidgets.interact(selectDestination, endLoc=selectDestinationWidget)

# widget for selecting the Destination
selectDestinationWidget=ipywidgets.Select(
    options=[
         'Bus Stop',
         'Laundry',
         'Homely',
         'Delhi Mess',
         'Urmidi Fastfood',
         'More SuperMarket',
         'Anjaneya Swami Temple',
         'Ground',
         'TT Quick Bites'
         ],
    value= 'Bus Stop',
    description='Target',
    disabled=False)

# widget function for selecting the Destination
def selectDestination(endLoc):
    global destination
    if endLoc == 'Bus Stop' :
       destination = 0
       drawMap()
    if endLoc == 'Laundry':
        destination = 1
        drawMap()
    if endLoc == 'Homely':
       destination = 3
       drawMap()
    if endLoc == 'Delhi Mess':
       destination = 8
       drawMap()
    if endLoc == 'Urmidi Fastfood':
      destination = 21
      drawMap()
    if endLoc == 'More SuperMarket':
        destination = 20
        drawMap()
    if endLoc == 'Anjaneya Swami Temple':
        destination = 22
        drawMap()
    if endLoc == 'Ground':
        destination = 25
        drawMap()
    if endLoc == 'TT Quick Bites' :
       destination = 28
       drawMap()

# Widget for selecting source
selectSourceWidget=ipywidgets.Select(
    options=[
             'Srishti PG',
             'Benaka Boys Hostel',
             ],
    value='Srishti PG',
    description='Start',
    disabled=False)

# widget function for selecting the source
def selectSource(startLoc):
    global source
    if startLoc == 'Srishti PG':
       source = 10
       getDestination()
    if startLoc == 'Benaka Boys Hostel':
        source = 11
        getDestination()
  
getSource()

# while(True):
#     totalDistance = 0
#     source = int(input("Enter The Source Location : "))
#     destination = int(input("Enter the Destination Location : "))
#     myMap = folium.Map(location = defaultLocation, width = "100%%",height = "80%", zoom_start = 18,top="10%")
#     callBasicFunctions(source,destination)
#     print("\nTHE TOTAL DISTANCE COVERED : " + str(totalDistance))
#     folium.plugins.AntPath([antPath]).add_to(myMap)
#     display(myMap)
#     from IPython.display import clear_output
#     clear_output(wait=True)
# Out:
# interactive(children=(Select(description='Start', options=('Srishti PG', 'Benaka Boys Hostel'), value='Srishti…
